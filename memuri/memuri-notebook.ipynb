# %%
from users.models import AbstractUser
# Out:
# ---------------------------------------------------------------------------
# ImproperlyConfigured                      Traceback (most recent call last)
# <ipython-input-1-8cb103ddc969> in <module>()
# ----> 1 from users.models import AbstractUser
#
# /home/tom/dev/memuri_project/memuri/users/models.py in <module>()
#       1 # -*- coding: utf-8 -*-
#       2 # Import the AbstractUser model
# ----> 3 from django.contrib.auth.models import AbstractUser
#       4
#       5 # Import the basic Django ORM models library
#
# /home/tom/.virtualenvs/memuri/lib/python3.3/site-packages/django/contrib/auth/__init__.py in <module>()
#       4 from django.core.exceptions import ImproperlyConfigured, PermissionDenied
#       5 from django.utils.module_loading import import_by_path
# ----> 6 from django.middleware.csrf import rotate_token
#       7
#       8 from .signals import user_logged_in, user_logged_out, user_login_failed
#
# ...
